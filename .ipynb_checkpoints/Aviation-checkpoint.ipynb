# %% [markdown]
# Let's read in the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Read NTSB aviation accident data into dataframe, check the size

# %%
df = pd.read_csv('./AviationData.csv', engine='python')

# %%
num_rows = df.shape[0] #Provide the number of rows in the dataset
num_cols = df.shape[1] #Provide the number of columns in the dataset

print("there are {} rows in the dataset!".format(num_rows))
print("there are {} columns in the dataset!".format(num_cols))
# Out:
# there are 81013 rows in the dataset!
# there are 31 columns in the dataset!

# %% [markdown]
# Count the number of entries for each county

# %%
df['Country'].value_counts()
# Out:
# United States         76188
# Canada                  270
# Brazil                  246
# United Kingdom          230
# Mexico                  228
# Australia               217
# Bahamas                 196
# France                  171
# Germany                 163
# Colombia                140
# Spain                   114
# Venezuela                93
# Italy                    92
# Japan                    90
# Argentina                81
# Indonesia                76
# Ecuador                  74
# Peru                     74
# Russia                   68
# Switzerland              67
# Dominican Republic       56
# Guatemala                53
# Ireland                  52
# China                    49
# New Zealand              49
# Austria                  47
# Sweden                   41
# Chile                    40
# Netherlands              39
# Korea, Republic Of       39
#                       ...
# Palau                     1
# Macedonia                 1
# Senegal                   1
# Comoros                   1
# Montserrat                1
# Rwanda                    1
# Niger                     1
# Ivory Coast               1
# Madagascar                1
# Liberia                   1
# Libya                     1
# Eritrea                   1
# Malta                     1
# St Lucia                  1
# Sierra Leone              1
# Lebanon                   1
# Burma                     1
# Vanuatu                   1
# Oman                      1
# Benin                     1
# Laos                      1
# Isle of Man               1
# New Caledonia             1
# Anguilla                  1
# Yemen                     1
# Cambodia                  1
# Serbia                    1
# Guinea                    1
# Gibraltar                 1
# Nauru                     1
# Name: Country, Length: 177, dtype: int64

# %% [markdown]
# Clearly data from the United States dominate.
#
# Next look for column names and sample data in the dataset.

# %%
df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.Damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.Flight', 'Air.Carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.Phase.of.Flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
df.head().T
# Out:
#                                                 0  \
# Event.Id                           20171230X01728
# Investigation.Type                       Accident
# Accident.Number                        WPR18LA058
# Event.Date                             2017-12-29
# Location                       San Bernardino, CA
# Country                             United States
# Latitude                                  34.0917
# Longitude                                -117.248
# Airport.Code                                  SBD
# Airport.Name                  SAN BERNARDINO INTL
# Injury.Severity                         Non-Fatal
# Aircraft.Damage                       Substantial
# Aircraft.Category                        Airplane
# Registration.Number                        N222AT
# Make                                       CESSNA
# Model                                         210
# Amateur.Built                                  No
# Number.of.Engines                               1
# Engine.Type                         Reciprocating
# FAR.Description         Part 91: General Aviation
# Schedule                                      NaN
# Purpose.of.Flight                        Personal
# Air.Carrier                                   NaN
# Total.Fatal.Injuries                          NaN
# Total.Serious.Injuries                        NaN
# Total.Minor.Injuries                          NaN
# Total.Uninjured                                 1
# Weather.Condition                             VMC
# Broad.Phase.of.Flight                     LANDING
# Report.Status                         Preliminary
# Publication.Date                       2018-01-08
#
#                                                   1  \
# Event.Id                             20171229X23639
# Investigation.Type                         Accident
# Accident.Number                          GAA18CA094
# Event.Date                               2017-12-28
# Location                              Spearfish, SD
# Country                               United States
# Latitude                                    44.4847
# Longitude                                  -103.788
# Airport.Code                                    SPF
# Airport.Name            BLACK HILLS-CLYDE ICE FIELD
# Injury.Severity                           Non-Fatal
# Aircraft.Damage                         Substantial
# Aircraft.Category                          Airplane
# Registration.Number                           N11KX
# Make                                          PIPER
# Model                                    PA 32-301T
# Amateur.Built                                    No
# Number.of.Engines                                 1
# Engine.Type                                     NaN
# FAR.Description           Part 91: General Aviation
# Schedule                                        NaN
# Purpose.of.Flight                          Personal
# Air.Carrier                                     NaN
# Total.Fatal.Injuries                            NaN
# Total.Serious.Injuries                          NaN
# Total.Minor.Injuries                            NaN
# Total.Uninjured                                   1
# Weather.Condition                               VMC
# Broad.Phase.of.Flight                           NaN
# Report.Status                           Preliminary
# Publication.Date                         2018-01-09
#
#                                                 2                          3  \
# Event.Id                           20180102X10253             20171227X12320
# Investigation.Type                       Accident                   Accident
# Accident.Number                        CEN18LA064                 GAA18CA096
# Event.Date                             2017-12-28                 2017-12-27
# Location                             Paulding, OH             Upper Lake, CA
# Country                             United States              United States
# Latitude                                  41.1889                    39.4431
# Longitude                                -84.7081                    -122.96
# Airport.Code                                  NaN                        1Q5
# Airport.Name                                  NaN                        NaN
# Injury.Severity                         Non-Fatal                Unavailable
# Aircraft.Damage                       Substantial                        NaN
# Aircraft.Category                        Airplane                   Airplane
# Registration.Number                          N4JW                     N3945A
# Make                     PIPISTREL DOO AJDOVSCINA                 AEROPRO CZ
# Model                                    VIRUS SW                    EUROFOX
# Amateur.Built                                 NaN                         No
# Number.of.Engines                               1                          1
# Engine.Type                         Reciprocating                        NaN
# FAR.Description         Part 91: General Aviation  Part 91: General Aviation
# Schedule                                      NaN                        NaN
# Purpose.of.Flight                        Personal                   Personal
# Air.Carrier                                   NaN                        NaN
# Total.Fatal.Injuries                          NaN                        NaN
# Total.Serious.Injuries                        NaN                        NaN
# Total.Minor.Injuries                          NaN                        NaN
# Total.Uninjured                                 1                        NaN
# Weather.Condition                             VMC                        NaN
# Broad.Phase.of.Flight                      CRUISE                        NaN
# Report.Status                         Preliminary                Preliminary
# Publication.Date                       2018-01-04                 2018-01-08
#
#                                                      4
# Event.Id                                20171228X35517
# Investigation.Type                            Accident
# Accident.Number                             CEN18LA062
# Event.Date                                  2017-12-27
# Location                             Michigan City, IN
# Country                                  United States
# Latitude                                       41.6953
# Longitude                                      86.8256
# Airport.Code                                       MGC
# Airport.Name            Michigan City Municipal Airpor
# Injury.Severity                              Non-Fatal
# Aircraft.Damage                            Substantial
# Aircraft.Category                             Airplane
# Registration.Number                             N525KT
# Make                                            CESSNA
# Model                                             525A
# Amateur.Built                                       No
# Number.of.Engines                                  NaN
# Engine.Type                                        NaN
# FAR.Description              Part 91: General Aviation
# Schedule                                           NaN
# Purpose.of.Flight                          Positioning
# Air.Carrier                                        NaN
# Total.Fatal.Injuries                               NaN
# Total.Serious.Injuries                             NaN
# Total.Minor.Injuries                               NaN
# Total.Uninjured                                      2
# Weather.Condition                                  VMC
# Broad.Phase.of.Flight                          LANDING
# Report.Status                              Preliminary
# Publication.Date                            2018-01-08

# %% [markdown]
# Which fields has more NAN data?

# %%
df.isnull().mean()*100
# Out:
# Event.Id                   0.000000
# Investigation.Type         0.000000
# Accident.Number            0.000000
# Event.Date                 0.000000
# Location                   0.093812
# Country                    0.625825
# Latitude                  66.290595
# Longitude                 66.301705
# Airport.Code              43.518941
# Airport.Name              40.086159
# Injury.Severity            0.000000
# Aircraft.Damage            3.095799
# Aircraft.Category         70.097392
# Registration.Number        4.115389
# Make                       0.090109
# Model                      0.125906
# Amateur.Built              0.751731
# Number.of.Engines          5.355931
# Engine.Type                4.556059
# FAR.Description           70.480046
# Schedule                  85.646748
# Purpose.of.Flight          5.216447
# Air.Carrier               95.050177
# Total.Fatal.Injuries      30.467950
# Total.Serious.Injuries    33.390937
# Total.Minor.Injuries      31.981287
# Total.Uninjured           16.129510
# Weather.Condition          2.978534
# Broad.Phase.of.Flight      7.703702
# Report.Status              0.000000
# Publication.Date          16.954069
# dtype: float64

# %% [markdown]
# About 66% data don'e have Latitude/Longitude informaiton, about 40% data don't have airport information.
#
# Handel missing data:
# For Fatal.Injuries, Serious.Injuries, Minor.Injuries, Uninjured, fill missing data with 0. For Number.of.Engines, fill missing data with 1 (the majority of airplanes have only one engine)

# %%
df.fillna(value={'Total.Fatal.Injuries': 0,
                'Total.Serious.Injuries': 0,
                'Total.Minor.Injuries': 0,
                'Total.Uninjured': 0,
                'Number.of.Engines': 1}, 
          inplace = True)

# %% [markdown]
# Only keep fields we are interested in.

# %%
df = df[['Accident.Number',
        'Event.Date',
        'Location',
        'Country',
        'Investigation.Type',
        'Registration.Number',
        'Make',
        'Model',
        'Amateur.Built',
        'Number.of.Engines',
        'Total.Fatal.Injuries',
        'Total.Serious.Injuries',
        'Total.Minor.Injuries',
        'Total.Uninjured',
        'Broad.Phase.of.Flight']]

# %%
df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       81013.000000          81013.000000            81013.000000
# mean            1.139471              0.571698                0.214583
# std             0.437485              5.198918                1.130598
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             4.000000            349.000000              111.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          81013.000000     81013.000000
# mean               0.345636         4.890919
# std                2.303591        26.925647
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# 75%                0.000000         2.000000
# max              380.000000       699.000000

# %% [markdown]
# Notice the accident with greatest fatals have 349 fatals, let's check out what accident it is.

# %%
df.loc[df['Total.Fatal.Injuries']==349].T
# Out:
#                                    40130             40131
# Accident.Number              DCA97WA007B       DCA97WA007A
# Event.Date                    1996-11-12        1996-11-12
# Location                New Delhi, India  New Delhi, India
# Country                            India             India
# Investigation.Type              Accident          Accident
# Registration.Number                  NaN               NaN
# Make                             Tupolev            Boeing
# Model                             TU-154           747-168
# Amateur.Built                         No                No
# Number.of.Engines                      1                 1
# Total.Fatal.Injuries                 349               349
# Total.Serious.Injuries                 0                 0
# Total.Minor.Injuries                   0                 0
# Total.Uninjured                        0                 0
# Broad.Phase.of.Flight                NaN               NaN

# %% [markdown]
# It turns out it is the world's deadliest mid-air collision *1996 Charkhi Dadri mid-air collision*. The crash killed all 349 people on board both planes. Both airplanes have their entries in the NTSB dataset, but both listed 349 fatals in their entry. Saudi Arabian Airlines Boeing 747 had 312 Fatalities, Kazakhstan Airlines has 37 fatalities. Need to make correction to the dataset.

# %%
df.loc[df['Accident.Number']=='DCA97WA007A','Total.Fatal.Injuries'] = 312
df.loc[df['Accident.Number']=='DCA97WA007B','Total.Fatal.Injuries'] = 37

# %% [markdown]
# Now let's look at the September 11 attacks. 4 airplanes crashed on that day.

# %%
df.loc[df['Event.Date']=='2001-09-11']
# Out:
#       Accident.Number  Event.Date           Location        Country  \
# 29526      DCA01MA065  2001-09-11    Shanksville, PA  United States
# 29527      DCA01MA064  2001-09-11      Arlington, VA  United States
# 29528      DCA01MA063  2001-09-11  New York City, NY  United States
# 29529      DCA01MA060  2001-09-11  New York City, NY  United States
#
#       Investigation.Type Registration.Number    Make      Model Amateur.Built  \
# 29526           Accident              N591UA  Boeing        757            No
# 29527           Accident              N644AA  Boeing    757-200            No
# 29528           Accident              N612UA  Boeing  767-200ER            No
# 29529           Accident              N334AA  Boeing  767-200ER            No
#
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 29526                1.0                  44.0                     0.0
# 29527                1.0                  64.0                     0.0
# 29528                2.0                  65.0                     0.0
# 29529                2.0                  92.0                     0.0
#
#        Total.Minor.Injuries  Total.Uninjured Broad.Phase.of.Flight
# 29526                   0.0              0.0                CRUISE
# 29527                   0.0              0.0                CRUISE
# 29528                   0.0              0.0                CRUISE
# 29529                   0.0              0.0                CRUISE

# %% [markdown]
# Accidents with more than 250 fatalities:

# %%
df.loc[df['Total.Fatal.Injuries']>250].T
# Out:
#                                    5420              29244             40131  \
# Accident.Number               DCA14RA127        DCA02MA001       DCA97WA007A
# Event.Date                    2014-07-17        2001-11-12        1996-11-12
# Location                Hrabove, Ukraine  Belle Harbor, NY  New Delhi, India
# Country                          Ukraine     United States             India
# Investigation.Type              Accident          Accident          Accident
# Registration.Number                  NaN            N14053               NaN
# Make                              BOEING  Airbus Industrie            Boeing
# Model                          777 - 206       A300B4-605R           747-168
# Amateur.Built                         No                No                No
# Number.of.Engines                      1                 2                 1
# Total.Fatal.Injuries                 295               265               312
# Total.Serious.Injuries                 0                 0                 0
# Total.Minor.Injuries                   0                 0                 0
# Total.Uninjured                        0                 0                 0
# Broad.Phase.of.Flight                NaN           TAKEOFF               NaN
#
#                                             58931           67415
# Accident.Number                        DCA89RA014      DCA86RA010
# Event.Date                             1988-12-21      1985-12-12
# Location                LOCKERBIE, United Kingdom  GANDER, Canada
# Country                            United Kingdom          Canada
# Investigation.Type                       Accident        Accident
# Registration.Number                        N739PA          N950JW
# Make                                       BOEING         DOUGLAS
# Model                                     747-121         DC-8-63
# Amateur.Built                                  No              No
# Number.of.Engines                               4               4
# Total.Fatal.Injuries                          270             256
# Total.Serious.Injuries                          2               0
# Total.Minor.Injuries                            3               0
# Total.Uninjured                                 0               0
# Broad.Phase.of.Flight                         NaN             NaN

# %% [markdown]
# Look for the counts of each unique values (including NAN) in Investigation Type

# %%
vals = df['Investigation.Type'].value_counts(normalize=True, dropna=False)[:10]*100
vals.plot(kind="bar");

# %% [markdown]
# Majority of them are accident, only a small a fraction is incident.
# Look at country again, list the top 10 countries in the dataset:

# %%
vals = df['Country'].value_counts(normalize=True, dropna=False)[:10]*100
vals.plot(kind="bar");
plt.grid()

# %% [markdown]
# More than 90% data are from the United States, followed by Canada, Brazil, United Kindown, and Mexico.
#
# Now let's focus on these accident in the United States with at least one fatality, from data after Jan. 1982. (Data from before this month is not complete).

# %%
df['Date'] = pd.to_datetime(df['Event.Date'])
df.drop('Event.Date', axis=1, inplace=True)
df_fatal = df.loc[(df['Total.Fatal.Injuries']>1) &
           (df['Date']>='1982-01') &
           (df['Country'] == 'United States'),
            :]

# %% [markdown]
# How each aircaft model contributes to the fatal accidents.

# %%
vals = df_fatal['Make'].value_counts(normalize=True, dropna=False)[:20]*100
vals.plot(kind="bar");
plt.grid()

# %% [markdown]
# There is issue here, "CESSNA" (all CAPITALIZED) and "Cessna" (Only first letter Capitalized) has been listed as two separate models, so is "PIPER" and "Piper". Let's combined them by change all of them to upper case.

# %%
vals = df_fatal['Make'].str.upper().value_counts(normalize=True, dropna=False)[:20]*100
plt.figure(figsize=(8,6))
vals.plot(kind="bar");
plt.grid()
plt.title("Accident by aircraft models")
plt.show()

# %% [markdown]
# About 29% fatal accidents from Cessna, another 22% from Piper. 12% from Beech. It is not a surprise since Cessna, Piper Aircraft, and Beechcraft were considered the "Big Three" in the field of general aviation manufacturing.

# %%
vals = df_fatal['Amateur.Built'].value_counts(normalize=True, dropna=False)*100
plt.figure(figsize=(8,6))
vals.plot(kind="bar");
plt.grid()
plt.title("Accident by Amateur Built")
plt.show()

# %%
vals = df_fatal['Number.of.Engines'].value_counts(normalize=True, dropna=False)*100
plt.figure(figsize=(8,6))
vals.plot(kind="bar");
plt.grid()
plt.title("Accident by number of engines")
plt.show()

# %% [markdown]
# Check the fatal accident and fatality rate during each flight phase

# %%
vals = df_fatal['Broad.Phase.of.Flight'].value_counts(normalize=True, dropna=False)*100
plt.figure(figsize=(8,6))
vals.plot(kind="bar");
plt.grid()
plt.title("Fatal accidents during each flight phase")
plt.xlabel("Flight phase")
plt.ylabel("Fatal accident percentage during each flight phase")
plt.show()

# %%
vals = df_fatal.groupby(by='Broad.Phase.of.Flight')['Total.Fatal.Injuries'].sum().sort_values(ascending=False)
plt.figure(figsize=(8,6))
(vals/vals.sum()*100).plot(kind="bar");
plt.grid()
plt.title("Fatality during each flight phase")
plt.xlabel("Flight phase")
plt.ylabel("Fatality percentage during each flight phase")
plt.show()

# %% [markdown]
# The year to year Fatality rate

# %%
fatal_agg = df_fatal['Total.Fatal.Injuries'].groupby([df_fatal['Date'].dt.year]).agg({'sum','count'})
fatal_agg
# Out:
#          sum  count
# Date
# 1982  1264.0    352
# 1983   921.0    316
# 1984   889.0    310
# 1985  1088.0    302
# 1986   897.0    256
# 1987   956.0    255
# 1988   637.0    238
# 1989   832.0    251
# 1990   669.0    224
# 1991   786.0    231
# 1992   737.0    246
# 1993   587.0    208
# 1994   849.0    223
# 1995   547.0    202
# 1996   810.0    171
# 1997   762.0    187
# 1998   436.0    171
# 1999   480.0    171
# 2000   558.0    173
# 2001   968.0    164
# 2002   402.0    161
# 2003   521.0    191
# 2004   447.0    161
# 2005   402.0    153
# 2006   457.0    154
# 2007   378.0    143
# 2008   401.0    137
# 2009   391.0    129
# 2010   313.0    124
# 2011   323.0    116
# 2012   234.0     95
# 2013   277.0    106
# 2014   246.0     99
# 2015   266.0     97
# 2016   282.0     98
# 2017   203.0     81

# %%
plt.figure(figsize=(8,6))
plt.plot(fatal_agg[['sum','count']], 'o-', lw=4, ms=10 )
plt.legend(('Fatal counts', 'Fatal accidents'))
plt.title('Fatal accident historical trend')
plt.xlabel('Year')
plt.ylabel('Count')
plt.grid()
plt.show()

# %%
vals = df_fatal.groupby(by='Number.of.Engines')['Total.Fatal.Injuries'].sum().sort_values(ascending=False)
plt.figure(figsize=(8,6))
(vals/vals.sum()*100).plot(kind="bar");
plt.grid()
plt.title("Fatality for each engine numbers")
plt.xlabel("Number of engines")
plt.ylabel("Fatality percentage for each engine numbers")
plt.show()
